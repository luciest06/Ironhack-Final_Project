# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.datasets import load_digits
from sklearn.manifold import Isomap
import warnings
from sklearn import cluster
from matplotlib.colors import ListedColormap
from scipy.stats import chi2_contingency
from statsmodels.stats.proportion import proportions_ztest

# %% [markdown]
# ## Loading data

# %%
df = pd.read_csv('../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv')
display(df)
df.shape
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ## Creating color palette

# %%
color_1 = '#40E0D0'
colors = ['#40E0D0','#588c87','#53b6ac','#244f4b']

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.shape
# Out:
# (7043, 21)

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df_churn = df[df['Churn'] == 'Yes']
df_nochurn = df[df['Churn'] == 'No']

# %%
df_churn['gender'].value_counts(normalize= True)
# Out:
# gender
# Female    0.502408
# Male      0.497592
# Name: proportion, dtype: float64

# %%
df_nochurn['gender'].value_counts(normalize= True)
# Out:
# gender
# Male      0.507344
# Female    0.492656
# Name: proportion, dtype: float64

# %%
df_nochurn['SeniorCitizen'].value_counts(normalize= True)
# Out:
# SeniorCitizen
# 0    0.871279
# 1    0.128721
# Name: proportion, dtype: float64

# %%
df_churn['SeniorCitizen'].value_counts(normalize= True)
# Out:
# SeniorCitizen
# 0    0.745318
# 1    0.254682
# Name: proportion, dtype: float64

# %%
df[df['SeniorCitizen']==1]['Churn'].value_counts(normalize= True)
# Out:
# Churn
# No     0.583187
# Yes    0.416813
# Name: proportion, dtype: float64

# %%
df[df['SeniorCitizen']==0]['Churn'].value_counts(normalize= True)
# Out:
# Churn
# No     0.763938
# Yes    0.236062
# Name: proportion, dtype: float64

# %%
df['SeniorCitizen'].value_counts(normalize= True)
# Out:
# SeniorCitizen
# 0    0.837853
# 1    0.162147
# Name: proportion, dtype: float64

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['TotalCharges'].sort_values(ascending = True).head()
df['TotalCharges'].isna().sum()
df.dropna(subset=['TotalCharges'], inplace = True)

df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
#checking for outliers

numerical_features = ['tenure', 'MonthlyCharges','TotalCharges']

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for i,ax in zip(numerical_features, axes):
    ax.boxplot(x = df[i],boxprops=dict(color=color_1),whiskerprops=dict(color=color_1),capprops=dict(color=color_1))
    ax.set_title(i)
    
plt.show()

#does not seem to be any outlier

# %%
#categorize numerical features into different groups 

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

bins = [df['tenure'].min(),12,24,48,df['tenure'].max()]
labels = ['0-1 year','1-2 years','2-4 years','over 4 years']
df['tenure_cat'] = pd.cut(df['tenure'],bins=bins,labels=labels)
sns.histplot(df['tenure_cat'], ax=axes[0], color=color_1)
axes[0].set_title('Tenure Categories')
axes[0].tick_params(axis='x', rotation=30)

bins = [df['MonthlyCharges'].min(),30,50,80,100,df['MonthlyCharges'].max()]
labels = ['0-30','30-50','50-80','80-100','over 100']
df['MonthlyCharges_cat'] = pd.cut(df['MonthlyCharges'],bins=bins,labels=labels)
plt.xticks(rotation=30)
sns.histplot(df['MonthlyCharges_cat'], ax=axes[1],color=color_1)
axes[1].set_title('Monthly Charges Categories')
axes[1].tick_params(axis='x', rotation=30)

bins = [df['TotalCharges'].min(),100,500,1000,2000,5000,df['TotalCharges'].max()]
labels = ['0-100','100-500','500-1000','1000-2000','2000-5000','over 5000']
df['TotalCharges_cat'] = pd.cut(df['TotalCharges'],bins=bins,labels=labels)
plt.xticks(rotation=30)
sns.histplot(df['TotalCharges_cat'], ax=axes[2],color=color_1)
axes[2].set_title('Total Charges Categories')
axes[2].tick_params(axis='x', rotation=30)

# %%
warnings.filterwarnings('ignore')

categorical_features = ['gender', 'SeniorCitizen', 'Partner', 'Dependents','tenure_cat',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod','MonthlyCharges_cat','TotalCharges_cat']

fig, axes = plt.subplots(7, 3, figsize=(20, 30))  
axes = axes.flatten()

for col,ax in zip(categorical_features, axes):
    grouped_data = df.groupby(['Churn', col]).size().reset_index(name='Count')
    sns.barplot(x=col, y='Count', hue='Churn', data=grouped_data, ax=ax, palette=colors)
    ax.set_title(f'{col} Count Grouped by Churn')
    ax.tick_params(axis='x', rotation=30)    

plt.tight_layout()
plt.show()

# %%
warnings.filterwarnings('ignore')

numerical_features = ['tenure', 'MonthlyCharges','TotalCharges']

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for i,ax in zip(numerical_features, axes):
    sns.boxplot(x='Churn', y=i, data=df, ax=ax, palette=colors)
    ax.set_title(i)
    
plt.show()

# %% [markdown]
# ### First interpretations:
# Clients are more likely to churn if:
# - They have no dependent and no partner
# - They are a senior citizen (older than 65y)
# - They are recent customers (less than 1 year)
# - They have multiple lines (-> maybe because they will save more if they switch to a cheaper provider? could present specific offers for multiple lines)
# - They have fiber optic Internet service
# - They subscribe to Internet but do not subscribe to Online security, Online backup, Device protection, or Tech support services
# - Their contract is month-to-month
# - They pay via electronic check

# %% [markdown]
# ## Hypothesis testing

# %%
# H0: Customers who have been using Telco’s services for over 1 year are equally likely to churn as those who have been using it for less than or equal to 1 year.
# H1: Customers who have been using Telco’s services for over 1 year are less likely to churn.

df['tenure_group'] = np.where(df['tenure'] > 12, 'Over 1 years', '1 years or less')

contingency_table = pd.crosstab(df['tenure_group'], df['Churn'])

print("Contingency Table:\n", contingency_table)

chi2, p, dof, expected = chi2_contingency(contingency_table)

print(" ")
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p}\n")

alpha = 0.05  # Significance level

if p < alpha:
    print("We reject the null hypothesis. Customers who have been using Telco's services for over one year are less likely to churn.")
else:
    print("We fail to reject the null hypothesis. There's no significant difference in churn between the two groups.")
# Out:
# Contingency Table:
#  Churn              No   Yes
# tenure_group
# 1 years or less  1149  1037
# Over 1 years     4025   832
#
# Chi-Square Statistic: 708.78273968122
# P-Value: 3.68007400698092e-156
#
# We reject the null hypothesis. Customers who have been using Telco's services for over one year are less likely to churn.

# %%
# H0: Customers with month-to-month contracts are equally likely to churn as those with other types of contracts.
# H1: Customers with month-to-month contracts are more likely to churn.

df['ContractType'] = df['Contract'].apply(lambda x: 'Month-to-Month' if x == 'Month-to-month' else 'Other')

contingency_table = pd.crosstab(df['ContractType'], df['Churn'])

print("Contingency Table:\n", contingency_table)

chi2, p, dof, expected = chi2_contingency(contingency_table)

print(" ")
print(f"Chi-Square Statistic: {chi2}")
print(f"P-Value: {p}\n")

alpha = 0.05  # Significance level

if p < alpha:
    print("We reject the null hypothesis. Customers with month-to-month contracts are more likely to churn.")
else:
    print("We fail to reject the null hypothesis. There's no significant difference in churn rates based on contract type.")
# Out:
# Contingency Table:
#  Churn             No   Yes
# ContractType
# Month-to-Month  2220  1655
# Other           2954   214
#
# Chi-Square Statistic: 1153.9716611093477
# P-Value: 6.147585925549194e-253
#
# We reject the null hypothesis. Customers with month-to-month contracts are more likely to churn.

# %%
# H0: Senior citizens are equally likely to churn as non-senior citizens.
# H1: Senior citizens are more likely to churn than non-senior citizens.

senior_churn = df[df['SeniorCitizen'] == 1]['Churn'].value_counts()['Yes']
total_senior = df[df['SeniorCitizen'] == 1].shape[0]

non_senior_churn = df[df['SeniorCitizen'] == 0]['Churn'].value_counts()['Yes']
total_non_senior = df[df['SeniorCitizen'] == 0].shape[0]

successes = [senior_churn, non_senior_churn]
totals = [total_senior, total_non_senior]

# Perform the z-test
stat, pval = proportions_ztest(successes, totals)

print(f"Z-Statistic: {stat}")
print(f"P-Value: {pval}\n")

if pval < 0.05:
    print("We reject the null hypothesis. Senior citizens are more likely to churn.")
else:
    print("We fail to reject the null hypothesis. There is no significant difference in churn rates between senior and non-senior citizens.")
# Out:
# Z-Statistic: 12.663022223987696
# P-Value: 9.477903507376036e-37
#
# We reject the null hypothesis. Senior citizens are more likely to churn.

# %% [markdown]
# ## Clustering Algorithms

# %% [markdown]
# #### Transforming categorical features in numerical

# %%
df_categorical_features_for_dummification = df[['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'PaperlessBilling',
                                               'MultipleLines', 'InternetService', 'OnlineSecurity','OnlineBackup', 'DeviceProtection',
                                               'TechSupport', 'StreamingTV','StreamingMovies', 'Contract', 'PaymentMethod','Churn']]


df_dummified = pd.get_dummies(df_categorical_features_for_dummification)

df_numerical_features = df[['tenure', 'MonthlyCharges','TotalCharges']]

df_dummified = pd.concat([df_dummified,df_numerical_features],axis=1)
df_dummified
# Out:
#       SeniorCitizen  gender_Female  gender_Male  Partner_No  Partner_Yes  \
# 0                 0           True        False       False         True
# 1                 0          False         True        True        False
# 2                 0          False         True        True        False
# 3                 0          False         True        True        False
# 4                 0           True        False        True        False
# ...             ...            ...          ...         ...          ...
# 7038              0          False         True       False         True
# 7039              0           True        False       False         True
# 7040              0           True        False       False         True
# 7041              1          False         True       False         True
# 7042              0          False         True        True        False
#
#       Dependents_No  Dependents_Yes  PhoneService_No  PhoneService_Yes  \
# ...

# %% [markdown]
# ### Elbow Method without standardization and with PCA method

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

try:
    inertias = []

    for i in range(1,11):
        kmeans = KMeans(n_clusters=i)
        kmeans.fit(df_dummified)
        inertias.append(kmeans.inertia_)

    axes[0].plot(range(1,11), inertias, marker='o')
    axes[0].set_title('Elbow method')
    axes[0].set_xlabel('Number of clusters')
    axes[0].set_ylabel('Inertia')

except Exception as e:
    print('An error occurred:', str(e))

#The elbow method shows that 2 is a good value for K, so we retrain and visualize the result.

try:
    cmap = ListedColormap(colors[:3])

    pca = PCA(n_components=2)
    df_dummified_pca = pca.fit_transform(df_dummified)

    kmeans = KMeans(n_clusters=2)
    kmeans.fit(df_dummified_pca)
    
    axes[1].scatter(x=df_dummified_pca[:, 0], y=df_dummified_pca[:, 1], c=kmeans.labels_, cmap=cmap)
    axes[1].set_title('K-Means scatter after PCA')


except Exception as e:
    print('An error occurred:', str(e))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Elbow Method with Standardization

# %%
#trying with standardization of numerical data

standardizer = StandardScaler()
standardizer.fit(df_dummified)

np_dummified_stand = standardizer.transform(df_dummified)
df_dummified_stand = pd.DataFrame(np_dummified_stand, columns = df_dummified.columns,index=df_dummified.index)
df_dummified_stand
# Out:
#       SeniorCitizen  gender_Female  gender_Male  Partner_No  Partner_Yes  \
# 0         -0.440327       1.009430    -1.009430   -1.035617     1.035617
# 1         -0.440327      -0.990658     0.990658    0.965608    -0.965608
# 2         -0.440327      -0.990658     0.990658    0.965608    -0.965608
# 3         -0.440327      -0.990658     0.990658    0.965608    -0.965608
# 4         -0.440327       1.009430    -1.009430    0.965608    -0.965608
# ...             ...            ...          ...         ...          ...
# 7038      -0.440327      -0.990658     0.990658   -1.035617     1.035617
# 7039      -0.440327       1.009430    -1.009430   -1.035617     1.035617
# 7040      -0.440327       1.009430    -1.009430   -1.035617     1.035617
# 7041       2.271039      -0.990658     0.990658   -1.035617     1.035617
# 7042      -0.440327      -0.990658     0.990658    0.965608    -0.965608
#
#       Dependents_No  Dependents_Yes  PhoneService_No  PhoneService_Yes  \
# ...

# %% [markdown]
# #### Testing relevancy of PCA method

# %%
# Apply PCA
pca = PCA()
pca.fit(df_dummified_stand)  # Fit PCA to compute explained variance
df_pca = pca.fit_transform(df_dummified_stand)
explained_variance = pca.explained_variance_ratio_

# Check if the sum of the first two elements is less than 80%
if sum(explained_variance[:2]) < 0.80:
    print(f"PCA may not be optimal as the first two components explain only {sum(explained_variance[:2]): .2} of the variance, which is less than 80%.")
    print(" ")

print("Explained variance ratio:", pca.explained_variance_ratio_)
cmap = ListedColormap(colors[:3])
plt.scatter(df_pca[:, 0], df_pca[:, 1], c=df_dummified_stand['Churn_Yes'], cmap=cmap, s=30)
plt.colorbar(label='Digit Label')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('PCA 2D Projection')
plt.show()
# Out:
# PCA may not be optimal as the first two components explain only  0.38 of the variance, which is less than 80%.
#
# Explained variance ratio: [2.44948937e-01 1.36350969e-01 9.25408866e-02 5.44134750e-02
#  5.00926788e-02 4.26098823e-02 3.58545853e-02 3.33892176e-02
#  2.95503691e-02 2.85276131e-02 2.72601193e-02 2.60134092e-02
#  2.55830812e-02 2.46037605e-02 2.39741180e-02 2.27106856e-02
#  2.09745207e-02 1.96620556e-02 1.83626883e-02 1.73901451e-02
#  1.62514746e-02 7.67121915e-03 1.24367871e-03 2.04303003e-05
#  5.39880997e-17 3.86034770e-17 3.58487870e-17 2.92814434e-17
#  2.87280545e-17 2.27470521e-17 1.92627853e-17 1.73629833e-17
#  1.50575690e-17 1.15465051e-17 7.56029117e-18 4.57047850e-18
#  3.37515101e-18 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00]

# %% [markdown]
# #### Testing relevancy of Isomap method

# %%
warnings.filterwarnings('ignore')

try:
    embedding = Isomap(n_components=2)
    df_isomap = embedding.fit_transform(df_dummified_stand)
    print(df_isomap.shape)

except Exception as e:
    print('An error occurred:', str(e))
# Out:
# (7032, 2)

# %%
cmap = ListedColormap(colors[:3])

plt.scatter(df_isomap[:, 0], df_isomap[:, 1], c=df_dummified_stand['Churn_Yes'], cmap=cmap, s=30)

plt.colorbar(label='Digit Label')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('Isomap 2D Projection')
plt.show()

#Isomap method seems to be more relevant than PCA for the 2D projection as we discovered a 3rd cluster.

# %% [markdown]
# #### Testing relevancy of K-means algorithm

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

try:
    inertias = []

    for i in range(1,11):
        kmeans = KMeans(n_clusters=i, random_state=42)
        kmeans.fit(df_isomap)
        inertias.append(kmeans.inertia_)

    axes[0].plot(range(1,11), inertias, marker='o')
    axes[0].set_title('Elbow method')
    axes[0].set_xlabel('Number of clusters')
    axes[0].set_ylabel('Inertia')

except Exception as e:
    print('An error occurred:', str(e))

try:

    cmap = ListedColormap(colors[:3])
    
    embedding = Isomap(n_components=2)
    df_transformed = embedding.fit_transform(df_dummified_stand)
    kmeans = KMeans(n_clusters=3, random_state=42)
    kmeans.fit(df_transformed)
    scatter = axes[1].scatter(x=df_transformed[:, 0], y=df_transformed[:, 1], c=kmeans.labels_, cmap=cmap)
    axes[1].set_title('K-Means scatter after Isomap')
    plt.colorbar(scatter, ax=axes[1], label='Cluster Label')

except Exception as e:
    print('An error occurred:', str(e))

plt.tight_layout()
plt.show()

# %%
range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(df_isomap)
    silhouette_avg = silhouette_score(df_isomap, kmeans.labels_)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)


#We proved visually and with the average silhouette metric that we could analyse our dataset using 3 clusters.
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.6287866644619318
# For n_clusters = 3 The average silhouette_score is : 0.6834975292525928
# For n_clusters = 4 The average silhouette_score is : 0.5229949160215177
# For n_clusters = 5 The average silhouette_score is : 0.509927850952412
# For n_clusters = 6 The average silhouette_score is : 0.48045968416837737

# %% [markdown]
# #### Testing relevancy of HDBSCAN algorithm

# %%
#allow_single_cluster: True,
#hdbscan_min_cluster_size: 15,
#hdbscan_min_samples: 3,
#random_state = 42

try:
    cmap = ListedColormap(colors[:3])

    hdbscan = cluster.HDBSCAN(min_samples=3, min_cluster_size=15, allow_single_cluster=True)

    hdbscan.fit(df_isomap)

    plt.scatter(df_isomap[:, 0], df_isomap[:, 1], s=10, c=hdbscan.labels_, cmap=cmap)
    plt.xlim(-30, 50)
    plt.ylim(-30, 50)
    plt.title('HDBSCAN scatter after Isomap')
    plt.colorbar(label='Cluster Label')

except Exception as e:
    print('An error occurred:', str(e))

plt.show()

# HDBSCAN is not the optimal algorithm here as it did not identify the 3 clusters, which are however clearly defined on the graph.
# We can indeed notice that the hdbscan labels are not accurate.

# %% [markdown]
# ### Cluster Analysis

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(df_isomap)

df['Cluster'] = kmeans.labels_
df['Cluster'].value_counts()
# Out:
# Cluster
# 0    4832
# 1    1521
# 2     679
# Name: count, dtype: int64

# %%
categorical_features = ['gender', 'SeniorCitizen', 'Partner', 'Dependents','tenure_cat',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod','MonthlyCharges_cat','TotalCharges_cat','Churn']

fig, axes = plt.subplots(7, 3, figsize=(20, 30))  
axes = axes.flatten()

try: 
    for col,ax in zip(categorical_features, axes):
        grouped_data = df.groupby([col, 'Cluster']).size().reset_index(name='Count')
        sns.barplot(x='Cluster', y='Count', hue=col, data=grouped_data, ax=ax, palette = colors)
        ax.set_title(f'{col} Count Grouped by Cluster')
        ax.tick_params(axis='x', rotation=30)    
except Exception as e:
    print('An error occurred:', str(e))

plt.tight_layout()
plt.show()

# %%
numerical_features = ['tenure', 'MonthlyCharges','TotalCharges']

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for i,ax in zip(numerical_features, axes):
    sns.boxplot(x='Cluster', y=i, data=df, ax=ax, palette = colors)
    ax.set_title(i)
    
plt.show()

# %% [markdown]
# #### Cluster characteristics
#
# - Cluster 0 : customers who usually have no dependent, who are subscribing to phone, DSL, and fiber optic services. Most of them have a month-to-month contract, paperless billing, and pay with electronic check. Our highest paying customers are part of this population, median monthly charge is around USD 80. They have a 33% chance of churn.
#
# - Cluster 1 : customers subscribing to phone services but no internet service, usually having only one line, paying less than USD30 monthly mostly by mailed check, and mostly under 65 years old. These customers are unlikely to churn (less than 10%).
#
# - Cluster 2 : customers subscribing to DSL internet services but no phone service, paying between 0 and USD80 per month, with the majority of customers paying between USD30 and USD50. They have about 25% chance of churn.

# %% [markdown]
# ## Churn prediction with supervised machine learning models (if time permits)

# %% [markdown]
# ## Exporting tables for Dashboard visualisation

# %%
display(df)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.to_csv('../data/clean/Telco_df_with_clusters_and_ID.csv', index=False)
#df_dummified
#df_dummified_stand
